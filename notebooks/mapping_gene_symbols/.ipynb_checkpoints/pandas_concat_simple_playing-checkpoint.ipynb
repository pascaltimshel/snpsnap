# %%
import os
import sys
import glob
import collections

import pandas as pd
import numpy as np

import ipdb

# %%
#df = pd.DataFrame(np.random.randn(4, 10), index=['C', 'A', 'A', 'C'])
df = pd.DataFrame(np.random.randn(4, 10), index=[2, 1, 1, 3])
df
# Out:
#           0         1         2         3         4         5         6  \
# 2 -0.882174  2.329003  1.299767  0.173651 -0.200851 -0.600479 -0.986010
# 1 -0.863565  0.575907  2.125200  2.420424 -1.677527  0.159296  0.438492
# 1 -0.425575 -0.347390  1.652509 -1.985926 -0.034940  0.685112 -1.221989
# 3  0.288755  0.458604 -0.269382 -0.381077 -0.448129  0.070895  0.381967
#
#           7         8         9
# 2 -0.702508 -0.115040 -1.364135
# 1  0.255089 -2.528282  0.671322
# 1 -1.048946 -0.796373  0.482071
# 3  0.920301  0.301970  0.369671

# %% [markdown]
# # pd.concat(..., verify_integrity=True)

# %%
pieces = [df[:2], df[2:4]]

# %%
#concatenated = pd.concat(pieces, verify_integrity=True) #verify_integrity raises exception --> ValueError: Indexes have overlapping values: [1]
concatenated
# Out:
#           0         1         2         3         4         5         6  \
# 2 -0.882174  2.329003  1.299767  0.173651 -0.200851 -0.600479 -0.986010
# 1 -0.863565  0.575907  2.125200  2.420424 -1.677527  0.159296  0.438492
# 1 -0.425575 -0.347390  1.652509 -1.985926 -0.034940  0.685112 -1.221989
# 3  0.288755  0.458604 -0.269382 -0.381077 -0.448129  0.070895  0.381967
#
#           7         8         9
# 2 -0.702508 -0.115040 -1.364135
# 1  0.255089 -2.528282  0.671322
# 1 -1.048946 -0.796373  0.482071
# 3  0.920301  0.301970  0.369671

# %% [markdown]
# # drop.duplicates()

# %%
df3 = df
df3["index_tmp_col"] = df3.index
df3.drop_duplicates(cols='index_tmp_col', take_last=True, inplace=True)
del df3["index_tmp_col"]

# %%
df3
# Out:
#           0         1         2         3         4         5         6  \
# 2 -0.882174  2.329003  1.299767  0.173651 -0.200851 -0.600479 -0.986010
# 1 -0.425575 -0.347390  1.652509 -1.985926 -0.034940  0.685112 -1.221989
# 3  0.288755  0.458604 -0.269382 -0.381077 -0.448129  0.070895  0.381967
#
#           7         8         9
# 2 -0.702508 -0.115040 -1.364135
# 1 -1.048946 -0.796373  0.482071
# 3  0.920301  0.301970  0.369671
