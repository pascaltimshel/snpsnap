# %%
import os
import sys
import glob
import collections

import pandas as pd
import numpy as np

import re

import ipdb

# %%
file_db = "/Users/pascaltimshel/p_snpsnap/data/step3/1KG_snpsnap_production_v1_uncompressed_incl_rsID/ld0.5/ld0.5_db.h5"

# %%
store = pd.HDFStore(file_db, 'r')
df = store.get('dummy')
store.close()

# %%
df.head()
# Out:
#                       rsID  freq_bin  gene_count  dist_nearest_gene_snpsnap  \
# snpID
# 10:100115849  10:100115849        20           0                      39215
# 10:100146083  10:100146083         3           1                      28858
# 10:100183037  10:100183037        20           3                      23672
# 10:100276950  10:100276950        33           1                     718669
# 10:100294726  10:100294726        47           1                     700893
#
#               friends_ld01  friends_ld02  friends_ld03  friends_ld04  \
# snpID
# 10:100115849            39            12             8             7
# 10:100146083            39             0             0             0
# 10:100183037           230           175           157           149
# 10:100276950           189           157           146           123
# 10:100294726           308           183           176           143
#
#               friends_ld05  friends_ld06  friends_ld07  friends_ld08  \
# ...

# %% [markdown]
# # Sorting Index

# %%
#index_sorted = df.index.order() # works, sorts indexes
df_index_sorted = df.sort_index(axis=0).ix[:,'rsID']

# %%
df_index_sorted.head()
# Out:
# snpID
# 10:10000018       rs6602381
# 10:100000625      rs7899632
# 10:100000645     rs61875309
# 10:100002464    rs111551711
# 10:100002841    rs146107628
# Name: rsID, dtype: object

# %%
df_index_sorted[0]
# Out:
# str

# %%
#for index in df_index_sorted[:500]: # YOU CAN PRINT MORE IF YOU LIKE!
#    print index

counter = 0
for index, value in df_index_sorted.iteritems():
    print index, value
    counter += 1
    if counter == 500: break
# Out:
# 10:10000018 rs6602381
# 10:100000625 rs7899632
# 10:100000645 rs61875309
# 10:100002464 rs111551711
# 10:100002841 rs146107628
# 10:100003242 rs12258651
# 10:100003301 rs200623867
# 10:100003302 rs72828459
# 10:100003304 rs72828461
# 10:100003785 rs1359508
# 10:100004360 rs1048754
# 10:100004441 rs1048757
# 10:100004799 rs77264786
# 10:100004844 rs148752911
# 10:100004906 rs3750595
# 10:100004996 rs2025625
# 10:10000514 rs6602382
# 10:100005282 rs10786405
# 10:100007362 rs11816998
# 10:100007694 rs41307056
# 10:10000797 rs139197039
# 10:100008436 rs3793692
# 10:100009542 rs11598533
# 10:100010186 rs4919190
# 10:100010578 rs3750596
# 10:10001083 rs146350976
# 10:10001085 rs139360817
# 10:100011077 rs11189523
# 10:100011114 rs7082202
# 10:100011120 rs117258652
# 10:100011140 rs78500686
# 10:100011219 rs113644121
# 10:100011970 rs3750598
# 10:100012739 rs737656
# 10:100012890 rs737657
# 10:100013244 rs3750599
# 10:100013382 rs141995277
# 10:100013438 rs17524355
# 10:100013563 rs7086391
# ...

# %% [markdown]
# # Playing with printing Data Frame

# %%
df1 = df.ix[:50].copy() # this matrix corresponds to user input
df1.head()
# Out:
#                       rsID  freq_bin  gene_count  dist_nearest_gene_snpsnap  \
# snpID
# 10:100115849  10:100115849        20           0                      39215
# 10:100146083  10:100146083         3           1                      28858
# 10:100183037  10:100183037        20           3                      23672
# 10:100276950  10:100276950        33           1                     718669
# 10:100294726  10:100294726        47           1                     700893
#
#               friends_ld01  friends_ld02  friends_ld03  friends_ld04  \
# snpID
# 10:100115849            39            12             8             7
# 10:100146083            39             0             0             0
# 10:100183037           230           175           157           149
# 10:100276950           189           157           146           123
# 10:100294726           308           183           176           143
#
#               friends_ld05  friends_ld06  friends_ld07  friends_ld08  \
# ...

# %%
#df2plink = df1.ix[:,'rsID'] ## --> gives Series object
#df2plink['P'] = 0.00001


df2plink = df1.set_index('rsID')

# %%
df2plink.head()
# Out:
#               freq_bin  gene_count  dist_nearest_gene_snpsnap  friends_ld01  \
# rsID
# 10:100115849        20           0                      39215            39
# 10:100146083         3           1                      28858            39
# 10:100183037        20           3                      23672           230
# 10:100276950        33           1                     718669           189
# 10:100294726        47           1                     700893           308
#
#               friends_ld02  friends_ld03  friends_ld04  friends_ld05  \
# rsID
# 10:100115849            12             8             7             0
# 10:100146083             0             0             0             0
# 10:100183037           175           157           149            98
# 10:100276950           157           146           123            74
# 10:100294726           183           176           143           100
#
#               friends_ld06  friends_ld07  friends_ld08  friends_ld09
# rsID
# ...
