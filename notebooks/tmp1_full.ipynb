# %%
import os
import sys
import pandas as pd
import numpy as np
os.getcwd()
# Out:
# '/Users/pascaltimshel/git/snpsnap/notebooks'

# %%
store_path = '/Users/pascaltimshel/snpsnap/data/step3/test/ld0.5_db.h5'
store = pd.HDFStore(store_path, 'r') #
#df = store.get('dummy') # OK!

# %%
store.keys()
store.root.dummy.table.cols
store.get_storer('dummy')
# Out:
# frame_table  (typ->appendable,nrows->184693,ncols->4,indexers->[index],dc->[rsID,freq_bin,gene_count,dist_nearest_gene])

# %%
df.head()
# Out:
#                     rsID  freq_bin  gene_count  dist_nearest_gene
# snpID
# 8:67085800   rs117838274         1           1               2820
# 3:38424943   rs116646648         1           1              36597
# 4:20507804    rs74417123         1           2              22094
# 2:150423534  rs141575115         1           0              19869
# 8:76665584    rs72663517         1           1              33016
#
# [5 rows x 4 columns]

# %%
file_tab = '/Users/pascaltimshel/snpsnap/data/step3/test/ld0.5_collection.tab'

# %%
df_prim = pd.read_csv(file_tab, index_col=0, header=0, delim_whitespace=True, usecols=[0, 1, 2, 3, 4])

# %%
df_prim.head(200)
# Out:
#                      rsID  freq_bin  gene_count  dist_nearest_gene
# snpID
# 8:67085800    rs117838274         1           1               2820
# 3:38424943    rs116646648         1           1              36597
# 4:20507804     rs74417123         1           2              22094
# 2:150423534   rs141575115         1           0              19869
# 8:76665584     rs72663517         1           1              33016
# 20:31605067    rs17124001         1           1               9661
# 8:110606752   rs113602407         1           2               1720
# 10:77031653    rs75482812         1           0               2503
# 1:146835651   rs142962780         1          13              44823
# 16:13954597     rs2006860         1           0              59417
# 4:102983963    rs72922880         1           1              85912
# 4:187585691   rs139071096         1           1              76742
# 1:84403777     rs41293009         1           2              37938
# ...
